# %%
# Import libraries 
import pandas as pd
import csv 
from pathlib import Path
import matplotlib.pyplot as plt
import hvplot.pandas

# %%
# Read data
data_paths = [
    Path("cumulative_returns_2016_2017_R.csv"),
    Path("cumulative_returns_2018_2019_R.csv"),
    Path("cumulative_returns_2020_2021_D.csv"),
    Path("cumulative_returns_2022_2023_D.csv")
]
# Join data
dfs = [pd.read_csv(data_path) for data_path in data_paths]

# Define industries
industries = ['Tech', 'Health', 'Finance', 'Consumer', 'Energy', 'Weapons']

# Define year ranges
year_ranges = ["2016-2017(Republican)", "2018-2019(Republican)", "2020-2021(Democratic)", "2022-2023(Democratic)"]

# Plot each industry individually
for industry in industries:
    plt.figure(figsize=(10, 6))
    plt.title(f"Cumulative Returns for {industry}")
    for year, df in zip(year_ranges, dfs):
        plt.plot(df.index, df[industry], label=f"Year {year}")
    plt.xlabel("Trading Days")
    plt.ylabel("Cumulative Returns")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Tech" columns
tech_columns = combined_df.filter(like='Tech')

# Calculate the average of the "Tech" columns
tech_average = tech_columns.mean()

print(tech_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Tech" columns
# ----> 3 tech_columns = combined_df.filter(like='Tech')
#       5 # Calculate the average of the "Tech" columns
#       6 tech_average = tech_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Health" columns
health_columns = combined_df.filter(like='Health')

# Calculate the average of the "Tech" columns
health_average = health_columns.mean()

print(health_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Health" columns
# ----> 3 health_columns = combined_df.filter(like='Health')
#       5 # Calculate the average of the "Tech" columns
#       6 health_average = health_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Finance" columns
finance_columns = combined_df.filter(like='Finance')

# Calculate the average of the "Tech" columns
finance_average = finance_columns.mean()

print(finance_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Finance" columns
# ----> 3 finance_columns = combined_df.filter(like='Finance')
#       5 # Calculate the average of the "Tech" columns
#       6 finance_average = finance_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Consumer" columns
consumer_columns = combined_df.filter(like='Consumer')

# Calculate the average of the "Tech" columns
consumer_average = consumer_columns.mean()

print(consumer_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Consumer" columns
# ----> 3 consumer_columns = combined_df.filter(like='Consumer')
#       5 # Calculate the average of the "Tech" columns
#       6 consumer_average = consumer_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Energy" columns
energy_columns = combined_df.filter(like='Energy')

# Calculate the average of the "Tech" columns
energy_average = energy_columns.mean()

print(energy_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Energy" columns
# ----> 3 energy_columns = combined_df.filter(like='Energy')
#       5 # Calculate the average of the "Tech" columns
#       6 energy_average = energy_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
# Assuming df is your DataFrame containing the data
# Extract the "Weapons" columns
weapons_columns = combined_df.filter(like='Weapons')

# Calculate the average of the "Tech" columns
weapons_average = weapons_columns.mean()

print(weapons_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Assuming df is your DataFrame containing the data
#       2 # Extract the "Weapons" columns
# ----> 3 weapons_columns = combined_df.filter(like='Weapons')
#       5 # Calculate the average of the "Tech" columns
#       6 weapons_average = weapons_columns.mean()
#
# NameError: name 'combined_df' is not defined

# %%
print(weapons_average)
print(energy_average)
print(consumer_average)
print(finance_average)
print(health_average)
print(tech_average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(weapons_average)
#       2 print(energy_average)
#       3 print(consumer_average)
#
# NameError: name 'weapons_average' is not defined

# %% [markdown]
# Top Performers 1 year after Midterm Election
# Finance - 1.187
# Tech - 1.180
# Consumer Discretionary - 1.34
